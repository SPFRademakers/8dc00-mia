# %%
import numpy as np
import matplotlib.pyplot as plt

# train subject 1
atlas_dc_1  = np.array([0.5323, 0.5650, 0.4964, 0.5137, 0.5628])
kNN_dc_1    = np.array([0.7828, 0.7290, 0.7133, 0.6709, 0.7296])
my_dc_1     = np.array([0.7868, 0.7209, 0.7018, 0.7036, 0.7124])

atlas_err_1 = np.array([0.2070, 0.1750, 0.2060, 0.2199, 0.1885])
kNN_err_1   = np.array([0.1095, 0.1201, 0.1507, 0.1622, 0.1334])
my_err_1    = np.array([0.1092, 0.1228, 0.1513, 0.1446, 0.1384])

# train subject 2
atlas_dc_2  = np.array([])
kNN_dc_2    = np.array([])
my_dc_2     = np.array([])

atlas_err_2 = np.array([])
kNN_err_2   = np.array([])
my_err_2    = np.array([])

# train subject 3
atlas_dc_3  = np.array([])
kNN_dc_3    = np.array([])
my_dc_3     = np.array([])

atlas_err_3 = np.array([])
kNN_err_3   = np.array([])
my_err_3    = np.array([])

# train subject 4
atlas_dc_4  = np.array([])
kNN_dc_4    = np.array([])
my_dc_4     = np.array([])

atlas_err_4 = np.array([])
kNN_err_4   = np.array([])
my_err_4    = np.array([])

# train subject 5
atlas_dc_5  = np.array([])
kNN_dc_5    = np.array([])
my_dc_5     = np.array([])

atlas_err_5 = np.array([])
kNN_err_5   = np.array([])
my_err_5    = np.array([])

# total plot
train_1 = np.array([1, 1, 1, 1, 1])
train_2 = np.array([2, 2, 2, 2, 2])
train_3 = np.array([3, 3, 3, 3, 3])
train_4 = np.array([4, 4, 4, 4, 4])
train_5 = np.array([5, 5, 5, 5, 5])

atlas = plt.plot(train_1, atlas_dc_1, 'ro', train_2, atlas_dc_2, 'ro', train_3, atlas_dc_3, 'ro', train_4, atlas_dc_4, 'ro', train_5, atlas_dc_5, 'ro') 
kNN   = plt.plot(train_1, kNN_dc_1, 'bo', train_2, kNN_dc_2, 'bo', train_3, kNN_dc_3, 'bo', train_4, kNN_dc_4, 'bo', train_5, kNN_dc_5, 'bo')
my    = plt.plot(train_1, my_dc_1, 'ko', train_2, my_dc_2, 'ko', train_3, my_dc_3, 'ko', train_4, my_dc_4, 'ko', train_5, my_dc_5, 'ko')
plt.xlabel('train subject number')
plt.ylabel('dice score')
plt.legend(('atlas', 'kNN', 'combined method'),loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.plot(train_1, atlas_err_1, 'ro', train_2, atlas_err_2, 'ro', train_3, atlas_err_3, 'ro', train_4, atlas_err_4, 'ro', train_5, atlas_err_5, 'ro') 
plt.plot(train_1, kNN_err_1, 'bo', train_2, kNN_err_2, 'bo', train_3, kNN_err_3, 'bo', train_4, kNN_err_4, 'bo', train_5, kNN_err_5, 'bo')
plt.plot(train_1, my_err_1, 'ko', train_2, my_err_2, 'ko', train_3, my_err_3, 'ko', train_4, my_err_4, 'ko', train_5, my_err_5, 'ko')
plt.xlabel('train subject number')
plt.ylabel('error')
plt.legend(('atlas', 'kNN', 'combined method'),loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
